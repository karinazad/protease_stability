# %%
# %load_ext autoreload
# %autoreload 2

import os 
import sys

ROOT_PATH = os.path.dirname(os.getcwd())
sys.path.append(ROOT_PATH)

from src.evals.hyperparameter_search import run_hyperparameter_search
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from 

DATA_PATH = os.path.join(ROOT_PATH, "data/210728_scrambles_for_unstructure_model.csv")
SAVE_DIR = os.path.join(ROOT_PATH, "results")

N_ITER = 5
PARAMETERS = {
    "num_conv_layers": [1, 2, 3],
    "padding": ["valid", "causal"],
    "num_filters": [32, 64, 128, 256, 512, 1028],
    "kernel_size": [3, 5, 8, 10, 12, 15],
    "strides": [1, 2, 3],
    "embdedding_output_dim": [32, 64, 128, 256, 512],
}

# %%
run_hyperparameter_search(parameters = PARAMETERS,
                          n_iter = N_ITER,
                          data_path = DATA_PATH,
                          save_dir = SAVE_DIR)
# Out:
# ------ HYPERPARAMETER SEARCH ------
# TRIAL 1/5:
# 380/380 [==============================] - 14s 33ms/step - loss: 1.4473 - Trypsin_loss: 0.6870 - Chemotrypsin_loss: 0.7602 - Trypsin_mse: 0.6870 - Chemotrypsin_mse: 0.7602 - val_loss: 1.2743 - val_Trypsin_loss: 0.6063 - val_Chemotrypsin_loss: 0.6680 - val_Trypsin_mse: 0.6063 - val_Chemotrypsin_mse: 0.6680
# 268/268 [==============================] - 1s 4ms/step - loss: 1.2743 - Trypsin_loss: 0.6063 - Chemotrypsin_loss: 0.6680 - Trypsin_mse: 0.6063 - Chemotrypsin_mse: 0.6680
# 		Score: total loss = 1.2743048667907715, trypsin loss = 0.6062710285186768, chemotrypsin loss = 0.66803377866745
#
#
# TRIAL 2/5:
#  68/380 [====>.........................] - ETA: 3:05 - loss: 1.5146 - Trypsin_loss: 0.7191 - Chemotrypsin_loss: 0.7955 - Trypsin_mse: 0.7191 - Chemotrypsin_mse: 0.7955
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-cc691681ad4e> in <module>
#       2                           n_iter = N_ITER,
#       3                           data_path = DATA_PATH,
# ----> 4                           save_dir = SAVE_DIR)
#
# ~/Desktop/Rocklin Lab/Projects/protease_stability/protease_stability/src/hyperparameter_search.py in run_hyperparameter_search(parameters, n_iter, data_path, save_dir, suffix)
#      54                                 epochs=1,
#      55                                 batch_size=128,
# ---> 56                                 callbacks=[callback])
#      57
#      58             loss, y1_loss, y2_loss, _, _ = model.evaluate(X_val, [y1_val, y2_val])
#
# /opt/anaconda3/envs/tf2env/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1181                 _r=1):
#    1182               callbacks.on_train_batch_begin(step)
# -> 1183               tmp_logs = self.train_function(iterator)
#    1184               if data_handler.should_sync:
#    1185                 context.async_wait()
#
# /opt/anaconda3/envs/tf2env/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# /opt/anaconda3/envs/tf2env/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# /opt/anaconda3/envs/tf2env/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3022        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3023     return graph_function._call_flat(
# -> 3024         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3025
#    3026   @property
#
# /opt/anaconda3/envs/tf2env/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1959       # No tape is watching; skip to running the function.
#    1960       return self._build_call_outputs(self._inference_function.call(
# -> 1961           ctx, args, cancellation_manager=cancellation_manager))
#    1962     forward_backward = self._select_forward_and_backward_functions(
#    1963         args,
#
# /opt/anaconda3/envs/tf2env/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     594               inputs=args,
#     595               attrs=attrs,
# --> 596               ctx=ctx)
#     597         else:
#     598           outputs = execute.execute_with_cancellation(
#
# /opt/anaconda3/envs/tf2env/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:
